# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
# print(os.listdir("../input"))

# %%
df = pd.read_csv('data.csv')
# df.head(5)

# %%
# len(df)

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
df[df.budget == df.budget.max()]
# ответ The Warrior's Way
answer_ls.append(4)

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
df[df.runtime == df.runtime.max()]
# ответ Gods and Generals
answer_ls.append(2)

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
df[df.runtime == df.runtime.min()]
# ответ Winnie the Pooh
answer_ls.append(3)

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
df.runtime.mean()
# ответ 110
answer_ls.append(2)

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
df.runtime.median()
# ответ 106
answer_ls.append(1)

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
# в DF добавляем колонку с расчитанным доходом/расходом. Для дальнейшего использования
df['profit'] = df.revenue - df.budget 
df[df.profit == df.profit.max()]

# ответ Avatar
answer_ls.append(5)

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
df[df.profit == df.profit.min()]
# ответ The Warrior's Way
answer_ls.append(2)

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
df[df.profit > 0].original_title.count() #считаем количество фильмов с доходом больше 0

# ответ 1478
answer_ls.append(1)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
reven = df[df.release_year == 2008].revenue.max() # определяем размер максимальной кассы фильмов из 2008
df[df.revenue == reven] # извлекаем данные по условию

# ответ The Dark Knight
answer_ls.append(4)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
df[df.profit == (df.query('2012 <= release_year <= 2014').profit.min())] # сортируем по году и максимальному убытку
# ответ The Lone Ranger
answer_ls.append(5)

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
import collections

genres = df.genres.str.split('|')

genre = Counter()

for gen in genres:
    genre += Counter(gen)
genre.most_common()
# ответ ('Drama', 782)
answer_ls.append(3)

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
profit_movies = df[df.profit > 0] #фильтруем DF по доходу

genres = profit_movies.genres.str.split('|') #выделяем жанры
genre = Counter()

for gen in genres:
    genre += Counter(gen)
genre.most_common()  # выводим наиболее часто повторяющийся
# ответ ('Drama', 560)
answer_ls.append(1)

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
df['director'].value_counts()
# ответ Steven Soderbergh  13
answer_ls.append(3)

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
# фильтруем по положительному доходу
profit_movies = df[df.profit > 0] 
profit_movies
profit_movies.director.value_counts()
# ответ Ridley Scott 12
answer_ls.append(4)

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
df1 = pd.pivot_table(df, values = 'profit', 
                     index = 'director', 
                     aggfunc = sum).sort_values('profit', ascending = False).head(1)
df1.index
# ответ Peter Jackson	5202593685
answer_ls.append(5)

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
#выделяем отдельно актеров
df_cast = pd.DataFrame(df.cast.str.split('|').tolist()).stack().reset_index() 

#именуем столбцы нового DF
df_cast.columns = ['row_index','row2','cast']

#добавляем новый столбец profit 
df_cast['profit_cast'] = df_cast.row_index.apply(lambda x : df.iloc[x]['profit']) 

#строим сводную таблицу для актеров с указанием их доходности
table = pd.pivot_table(df_cast, values = 'profit_cast', 
                       index = 'cast', 
                       aggfunc = sum).sort_values('profit_cast', ascending = False)
table

# ответ Emma Watson 
answer_ls.append(1)

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
#фильтруем DF по году
df_year = df[df.release_year == 2012] 

#выделяем актеров
df_cast = pd.DataFrame(df_year.cast.str.split('|').tolist()).stack().reset_index()

#именуем столбцы нового DF
df_cast.columns = ['row_index','row2','cast'] 

#добавляем новые столбцы
df_cast['Profit_cast'] = df_cast.row_index.apply(lambda x:df_year.iloc[x]['profit']) 
df_cast['Year'] = df_cast.row_index.apply(lambda x: df_year.iloc[x]['release_year'])

#строим сводную таблицу для актеров с указанием их доходности
table = pd.pivot_table(df_cast, values = 'Profit_cast', index = 'cast', aggfunc = sum).sort_values('Profit_cast', ascending = True)
table
# Ответ: Kirsten Dunst	-68109207
answer_ls.append(3)

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
df_budget = df[df.budget > df.budget.mean()] #фильтр по бюджету выше среднего

df_cast = pd.DataFrame(df_budget.cast.str.split('|').tolist()).stack().reset_index() #выделяем актеров
df_cast.columns = ['1','2','cast'] #именуем столбцы
df_cast.cast.value_counts() #считаем количество повторений актеров в высокобюджетных фильмах
# ответ: Matt Damon  18
answer_ls.append(3)

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
#выделяем актеров
df_cast = pd.DataFrame(df.cast.str.split('|').tolist()).stack().reset_index() 

#именуем столбцы
df_cast.columns = ['raw_index','index','cast'] 

#новый столбец с жанрами
df_cast['genre'] = df_cast.raw_index.apply(lambda x: df.iloc[x]['genres']) 

#филтруем по Кейджу
df_cage = df_cast[df_cast.cast == 'Nicolas Cage'] 

#выделяем жанры
df_genre = pd.DataFrame(df_cage.genre.str.split('|').tolist()).stack().reset_index() 

# именуем колонки для простоты обращения
df_genre.columns = ['1','2','genre']

df_genre.genre.value_counts()

# ответ: Action
answer_ls.append(2)

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
# выделяем компании
df_company = pd.DataFrame(df.production_companies.str.split('|').tolist()).stack().reset_index()

#именуем столбцы
df_company.columns = ['1','2','company'] 

df_company.company.value_counts()

# ответ: Universal Pictures 173
answer_ls.append(1)

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
# фильтруем по году
df_year = df[df.release_year == 2015]

# выделяем компании
df_company = pd.DataFrame(df_year.production_companies.str.split('|').tolist()).stack().reset_index()

# именуем столбцы
df_company.columns = ['1','2','company']

# считаем повторения
df_company.company.value_counts()

# ответ: Warner Bros.  12
answer_ls.append(4)

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
# готовим данные: выделяем студии и жанры
df_company = pd.DataFrame(df.production_companies.str.split('|').tolist()).stack().reset_index()
df_company.columns = ['common_index', 'index','company']
df_company['genres'] = df_company.common_index.apply(lambda x: df.iloc[x]['genres'])
df_genres = pd.DataFrame(df_company.genres.str.split('|').tolist()).stack().reset_index()
df_genres.columns = ['common_index', 'index', 'genre']

#удаляем не нужный столбец
df_company.drop(['genres'], axis = 1, inplace = True)

#объединяем выделенные жанры и компании
df_common = df_company.merge(df_genres, on = 'common_index')

#считаем количество повторений
df_common[df_common.genre == 'Comedy'].company.value_counts()

# Ответ: Universal Pictures
answer_ls.append(2)

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
# готовим данные. Фильтруем по году, выделаям наименования компаний
df_comp = df[df.release_year == 2012]
df_company = pd.DataFrame(df_comp.production_companies.str.split('|').tolist()).stack().reset_index()

# именуем столбцы
df_company.columns = ['raw_index','index','company']

# добавляем колонку дохода
df_company['profits'] = df_company.raw_index.apply(lambda x: df.iloc[x]['profit'])

# строим сводную таблицу для компаний и их доходов
table = pd.pivot_table(df_company, values = 'profits', 
                       index = 'company', aggfunc = sum).sort_values('profits', ascending = False)

table
# ответ Columbia Pictures	2501406608
answer_ls.append(3)

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
# готовим данные, выделяем компании
df_paramount = pd.DataFrame(df.production_companies.str.split('|').tolist()).stack().reset_index()

# именуем колонки
df_paramount.columns = ['raw_index','index','company']

# создаем две новые колонки
df_paramount['movie'] = df_paramount.raw_index.apply(lambda x: df.iloc[x]['original_title'])
df_paramount['profit']=df_paramount.raw_index.apply(lambda x: df.iloc[x]['profit'])

# фильтруем по наименованию нужной компании
df_paramount.query('company in ["Paramount Pictures"]').sort_values('profit',ascending = True)

# ответ: K-19: The Widowmaker
answer_ls.append(1)

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
group = df.groupby('release_year')['profit'].agg([sum])
answer_ls.append(5)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
# готовим DF с нужными данными
df_warner = pd.DataFrame(df.production_companies.str.split('|').tolist()).stack().reset_index()
df_warner.columns = ['raw_index','index','company']

df_warner['profit']=df_warner.raw_index.apply(lambda x: df.iloc[x]['profit'])
df_warner['year'] = df_warner.raw_index.apply(lambda x: df.iloc[x]['release_year'])

# фильтруем DF по компании
df_wb = df_warner[df_warner.company.str.contains('Warner Bros.')]

#группируем по годам
group = pd.DataFrame(df_wb.groupby('year')['profit'].sum())

# фильтруем по максимальному значению
group[group.profit == group.profit.max()]

# ответ: 2014
answer_ls.append(1)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
# фильтр данных
df_release = df[['original_title','release_year','release_date']]

# преобразовываем дату в нужный формат, выделяем наименование месяца
df_release['release_date'] = pd.to_datetime(df_release.release_date)
df_release['month'] = df_release.release_date.dt.strftime('%B')

df_release['month'].value_counts()

# ответ: сентябрь
answer_ls.append(4)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
# подготовка данных
df_release = df[['original_title']]
df['release_date'] = pd.to_datetime(df.release_date)

df_release['month'] = df.release_date.dt.strftime('%B')

# длина списка состоящего из фильмов вышедших в нужные месяца
len(df_release[(df_release.month == 'June') | ((df_release.month == 'July') | (df_release.month == 'August'))])

# ответ: 450 
answer_ls.append(2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
df_director = df
# подготовка данных
df_director['release_date'] = pd.to_datetime(df_director.release_date)

# добавляем колонку
df_director['month'] = df_director.release_date.dt.strftime('%B')

# фильтруем по зиме и считаем количество
df_director = df_director.query('month in ["December","January","February"]')
df_director['director'].value_counts()


# ответ Peter Jackson
answer_ls.append(5)

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
df_profit = df

# подготовка данных
df_profit['release_date'] = pd.to_datetime(df.release_date)
df_profit['month'] = df.release_date.dt.strftime('%B')
df_profit


# готовим сводную таблицу для прибыли по месяцам
table = pd.pivot_table(df_profit, values = 'profit', 
                       index = 'month', aggfunc = 'sum').sort_values('profit', ascending = False)

table
    
# ответ: June
answer_ls.append(2)

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
# подготовка данных, выделение наименования компаний.
df_movie = pd.DataFrame(df.production_companies.str.split('|').tolist()).stack().reset_index()

# именуем колонки
df_movie.columns = ['common_index','index','company']

# создаем новые колонки
df_movie['title'] = df_movie.common_index.apply(lambda x: df.iloc[x]['original_title'])

df_movie['lenght'] = df_movie.common_index.apply(lambda x: len(df.iloc[x]['original_title']))

# сводная таблица для вывода информации о длинне названий фильмов и имен компаний
table = pd.pivot_table(df_movie, 
                       values = 'lenght', 
                       index = 'company', aggfunc = 'mean').sort_values('lenght',ascending = False)

table

# ответ: Four By Two Productions	83.0
answer_ls.append(5)

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
# готовим данные, выделяем имена компаний, именуем колонки, создаем колонки movie и number_of_words
df_movie = pd.DataFrame(df.production_companies.str.split('|').tolist()).stack().reset_index()
df_movie.columns = ['common_index','index', 'company']
df_movie['movie'] = df_movie.common_index.apply(lambda x: df.iloc[x]['original_title'])
df_movie['numbers_of_words'] = df_movie.movie.apply(lambda x: len(x.split(' ')))

# фильтруем по максимальной длине (количеству слов)
df_movie[df_movie.numbers_of_words == df_movie.numbers_of_words.max()]

# сводная таблица с общей инфой по компаниям и количеству слов в названии
table = pd.pivot_table(df_movie, values = 'numbers_of_words', 
                       index = 'company', aggfunc = 'mean').sort_values('numbers_of_words', ascending = False)
table


# ответ: Four By Two Productions	12.0
answer_ls.append(5)

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
# готовим данные. Переводим вссе наименования в нижний регистр
df_movie = pd.DataFrame(df.original_title.str.lower())

# выделяем наименования фильмов, именуем колонки
df_movie = pd.DataFrame(df_movie.original_title.str.split(' ').tolist()).stack().reset_index()
df_movie.columns = ['common_index', ' index', 'word']

# считаем количество уникальных повторений
df_movie.word.nunique()

# ответ: 2462
answer_ls.append(3)

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
df_ratings = df

# готовим данные, сортируем по рейтингу, именуем колонки
df_ratings = df_ratings[['original_title','vote_average']].sort_values('vote_average', ascending = False)
df_ratings.columns = ['title','ratings']

# фильтруем по условию: рейтинг больше, чем у 99%
df_ratings[df_ratings['ratings'] > df_ratings.quantile(0.99, numeric_only=True)['ratings']]

# ответ: Inside Out, Gone Girl, 12 Years a Slave

answer_ls.append(1)

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
import itertools as its
df_actor = df

# создаем дополнительно колонку с именами актеров
df_actor['actor_list'] = pd.DataFrame(df.cast.str.split('|'))

# группируем попарно
df_final = pd.DataFrame(df_actor['actor_list'].apply(lambda x: Counter(its.combinations(x, 2))))

# проверяем наиболее часто повторяющиеся пары
display(df_final.actor_list.sum().most_common())

# ответ: ('Daniel Radcliffe', 'Rupert Grint'), 8)
answer_ls.append(5)
# Out:
# [(('Daniel Radcliffe', 'Rupert Grint'), 8),
#  (('Daniel Radcliffe', 'Emma Watson'), 8),
#  (('Rupert Grint', 'Emma Watson'), 7),
#  (('Ben Stiller', 'Owen Wilson'), 6),
#  (('Johnny Depp', 'Helena Bonham Carter'), 6),
#  (('Adam Sandler', 'Kevin James'), 5),
#  (('Hugh Jackman', 'Ian McKellen'), 5),
#  (('Kristen Stewart', 'Robert Pattinson'), 5),
#  (('Kristen Stewart', 'Taylor Lautner'), 5),
#  (('Robert Pattinson', 'Taylor Lautner'), 5),
#  (('Jennifer Lawrence', 'Josh Hutcherson'), 4),
#  (('Jennifer Lawrence', 'Liam Hemsworth'), 4),
#  (('Jennifer Lawrence', 'Woody Harrelson'), 4),
#  (('Josh Hutcherson', 'Liam Hemsworth'), 4),
#  (('Josh Hutcherson', 'Woody Harrelson'), 4),
#  (('Liam Hemsworth', 'Woody Harrelson'), 4),
#  (('Tobin Bell', 'Costas Mandylor'), 4),
#  (('Tobin Bell', 'Betsy Russell'), 4),
#  (('Costas Mandylor', 'Betsy Russell'), 4),
#  (('Vin Diesel', 'Jordana Brewster'), 4),
#  (('Paul Walker', 'Jordana Brewster'), 4),
#  (('Mike Myers', 'Eddie Murphy'), 4),
# ...

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
# выделяем режиссеров поименно
data_director = pd.DataFrame(df.director.str.split('|').tolist()).stack().reset_index()

# именуем колонки
data_director.columns = ['common_index','index','director']

# создаем колонку movie 
data_director['movie'] = data_director.common_index.apply(lambda x: df.iloc[x]['original_title'])

# создаем колонку с прибылью
data_director['profit'] = data_director.common_index.apply(lambda x: df.iloc[x]['profit'])

# считаем общее количество фильмов для каждого режиссера
all_movies = pd.DataFrame(data_director['director'].value_counts())

# фильтруем режиссеров по количеству фильмов больше 7
all_movies = all_movies[all_movies.director > 7]

# фильтруем по прибыли больше 0
data_sorted = data_director[data_director.profit >= 0]

# считаем количество прибыльных фильмов на каждого режиссера
profit_movies = pd.DataFrame(data_sorted['director'].value_counts())

# принимаем количество прибыльных фильмов больше 7, как начальное условие
profit_movies = profit_movies[profit_movies.director > 7]

# делим прибыльные фильмы на общее количество
result = profit_movies.div(all_movies)

# получаем список режиссеров, подходящих под условие. Сверяем со списком - находим нужную фамилию.
display('result',result[result.director == result.director.max()])

# ответ: Christopher Nolan

answer_ls.append(4)
# Out:
# 'result'
#                    director
# Antoine Fuqua           1.0
# Brett Ratner            1.0
# Christopher Nolan       1.0
# Michael Bay             1.0
# Peter Jackson           1.0
# Ridley Scott            1.0
# Steven Spielberg        1.0
# Tim Burton              1.0

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       2
# 2    3       3
# 3    4       2
# 4    5       1
# 5    6       5
# 6    7       2
# 7    8       1
# 8    9       4
# 9   10       5
# 10  11       3
# 11  12       1
# 12  13       3
# 13  14       4
# 14  15       5
# 15  16       1
# 16  17       3
# 17  18       3
# 18  19       2
# 19  20       1
# 20  21       4
# 21  22       2
# 22  23       3
# 23  24       1
# 24  25       5
# 25  26       1
# 26  27       4
# 27  28       2
# 28  29       5
# 29  30       2
# 30  31       5
# 31  32       5
# 32  33       3
# 33  34       1
# 34  35       5
# 35  36       4
