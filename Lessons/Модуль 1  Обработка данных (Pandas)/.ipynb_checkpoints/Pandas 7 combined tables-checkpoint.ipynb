# %%
#                                                 Тестовые вопросы
import pandas as pd

ratings = pd.read_csv('ratings.xls')
movies = pd.read_csv('movies.xls')

display(ratings)
display(movies)

ratings['rating'].max()
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# ...

# %%
import pandas as pd

ratings = pd.read_csv('ratings.xls')
movies = pd.read_csv('movies.xls')

display(ratings.head())
display(movies)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
# ...

# %%
#                                       Объединение таблиц
# у movies и ratings есть общий стоблец movieid. Значит можно собрать эти DataFrame в один методом merge

joined = ratings.merge(movies, on = 'movieId', how = 'left')
display(joined.head())
len(ratings) == len(joined)

#Схематично метод merge можно описать так: joined = left_df.merge(right_df, on='', how='').
# left_df/right_df это таблицы, которые объединяем. К правому присоединяем левый
# on - определяет стоблец по которому происходит объединение. Если по нескольким, то ['col_1', 'col_2']


# how — параметр объединения записей. Он может иметь четыре значения: left, right, inner и outer. 
# При значении left берем все записи (movieId) из "левого" датафрейма (ratings) и ищем их соответствия в "правом" (movies). 
# В итоговом датафрейме останутся только те значения, которым были найдены соответствия, то есть только значения из ratings. 
# Аналогично при параметре right остаются только значения из "правого" датафрейма. 
# Если совпадений между таблицами нет, то ставим нулевое значение. 
# Значение inner оставляет только те записи (movieId), которые есть в обоих датафреймах, 
# outer объединяет все варианты movieId в обоих датафреймах. 

# joined = ratings.merge(movies, on = 'movieId', how = 'right')
# display(joined.head())
# len(ratings) == len(joined)

# joined = ratings.merge(movies, on = 'movieId', how = 'inner')
# display(joined.head())
# # len(ratings) == len(joined)

# joined = ratings.merge(movies, on = 'movieId', how = 'outer')
# display(joined.head())

# # len(ratings) == len(joined)
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller
# True

# %%
ratings = pd.read_csv('ratings_example.txt', sep = '\t')
movies = pd.read_csv('movies_example.txt', sep = '\t')
display(ratings, movies)

joined = ratings.merge(movies, on = 'movieId', how = 'right')
display('right', joined)

joined = ratings.merge(movies, on = 'movieId', how = 'left')
display('left', joined)

joined = ratings.merge(movies, on = 'movieId', how = 'inner')
display('inner', joined)

joined = ratings.merge(movies, on = 'movieId', how = 'outer')
display('outer', joined)
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
#    movieId                                      title                   genres
# 0       31                    Dangerous Minds (1995)                     Drama
# 1       32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 2       31                    Dangerous Minds (1995)                     Drama
# 'right'
#    userId  movieId  rating     timestamp  \
# 0     1.0       31     2.5  1.260759e+09
# 1     1.0       31     2.5  1.260759e+09
# 2     NaN       32     NaN           NaN
#
#                                        title                   genres
# 0                    Dangerous Minds (1995)                     Drama
# 1                    Dangerous Minds (1995)                     Drama
# 2  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 'left'
#    userId  movieId  rating   timestamp                    title genres
# ...

# %%
#                              Удаляем дубликаты строк после объединения
# метод drop_duplicates
movies.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
display(movies)

# subset - столбец, где ищем дубликаты. Можно указать несколько
# keep - какой оставляем?
# inplace - указывает, где сохраняем изменения. В том же DataFrame или нет
new = ratings.merge(movies, on = 'movieId', how = 'left')
display('new', new)
# Out:
#    movieId                                      title                   genres
# 0       31                    Dangerous Minds (1995)                     Drama
# 1       32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 'new'
#    userId  movieId  rating   timestamp                    title genres
# 0       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama

# %%
#                                                Задания
# наличие товара на складе
items_dict = {

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 

    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],

    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]

}

# данные о покупках товаров
purchase_log = {

    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 

    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]

}

# item_id — идентификатор модели (по этому столбцу будем объединять датафреймы)
# vendor — производитель модели
# stock_count — имеющееся на складе количество данных моделей (в штуках)
# purchase_id — идентификатор покупки
# price — стоимость модели в покупке


items_df = pd.DataFrame(items_dict)
purchase_df = pd.DataFrame(purchase_log)

display(items_df,purchase_df)

# purchase_df.merge(items_df, on = 'item_id', how = 'outer')
common = items_df.merge(purchase_df, on = 'item_id', how = 'inner')
display('common', common)
# items_df.merge(purchase_df, on = ['item_id', 'purchase_id'], how = 'left')

common_df = common['stock_count']*common['price']
display(common_df)


common = pd.concat([common, common_df], axis=1)
display(common)
common[common[0]==common[0].max()]
common[0].sum()
# Out:
#    item_id   vendor  stock_count
# 0   417283  Samsung           54
# 1   849734       LG           33
# 2   132223    Apple          122
# 3   573943    Apple           18
# 4    19475       LG          102
# 5  3294095    Apple           43
# 6   382043  Samsung           77
# 7   302948  Samsung          143
# 8   100132       LG           60
# 9   312394      ZTE           19
#    purchase_id  item_id  price
# 0          101   417283  13900
# 1          101   849734   5330
# 2          101   132223  38200
# 3          112   573943  49990
# 4          121    19475   9890
# 5          145  3294095  33000
# 6          145   382043  67500
# 7          145   302948  34500
# 8          145   103845  89900
# 9          221   100132  11400
# 'common'
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# ...

# %%
#                                      Объединение выгрузки данных

# получим список имен файлов в папке
import os

files = os.listdir('data')
files
# Out:
# ['ratings_1.txt',
#  'ratings_10.txt',
#  'ratings_2.txt',
#  'ratings_3.txt',
#  'ratings_4.txt',
#  'ratings_5.txt',
#  'ratings_6.txt',
#  'ratings_7.txt',
#  'ratings_8.txt',
#  'ratings_9.txt']

# %%
files = ['setup.py', 'ratings.txt', 'stock_stats.txt', 'movies.txt', 'run.sh', 'game_of_thrones.mov']
data = []

for item in files:
    if 'txt' in item:
        data.append(item)
    else:
        pass
print(data)
# Out:
# ['ratings.txt', 'stock_stats.txt', 'movies.txt']

# %%
for root,dirs,files in os.walk('data'):
    print(root,dirs,files)
# Out:
# data [] ['ratings_1.txt', 'ratings_10.txt', 'ratings_2.txt', 'ratings_3.txt', 'ratings_4.txt', 'ratings_5.txt', 'ratings_6.txt', 'ratings_7.txt', 'ratings_8.txt', 'ratings_9.txt']

# %%
#                                             Склеивание DataFrame
# при прохождении по файлам папки data будем записывать содержимое каждого файла в 
# датафрейм temp и добавлять его к итоговому датафрейму data. 
# Перед этим создадим пустой датафрейм data с нужными названиями столбцов:

data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp'])

for root,dirs,files in os.walk('data'):
    print(files)
    for filename in files:
        temp = pd.read_csv(os.path.join('data',filename), names = ['userId', 'movieId', 'rating', 'timestamp'])

        data = pd.concat([data,temp])
        
display(data)
# Out:
# ['ratings_1.txt', 'ratings_10.txt', 'ratings_2.txt', 'ratings_3.txt', 'ratings_4.txt', 'ratings_5.txt', 'ratings_6.txt', 'ratings_7.txt', 'ratings_8.txt', 'ratings_9.txt']
#      userId movieId  rating   timestamp
# 0         1      31     2.5  1260759144
# 1         1    1029     3.0  1260759179
# 2         1    1061     3.0  1260759182
# 3         1    1129     2.0  1260759185
# 4         1    1172     4.0  1260759205
# ...     ...     ...     ...         ...
# 9995    597    2572     3.0   940707828
# 9996    597    2613     3.0   940707355
# 9997    597    2657     4.0   940707124
# 9998    597    2661     4.0   940707609
# 9999    597    2662     3.0   940707473
#
# [100004 rows x 4 columns]

# %%
#                                        Тесты
# Сколько раз была выставлена низшая оценка 0.5 в наших рейтингах? Используйте файл ratings.csv.

ratings = pd.read_csv('ratings.xls')
ratings[ratings.rating == 0.5].rating.count()
display(ratings)
# Объедините датафреймы ratings и movies, используя параметр how='outer'. Сколько строк в получившемся датафрейме?
movies = pd.read_csv('movies.xls')

combined = ratings.merge(movies, on = 'movieId', how = 'outer')
combined

# Найдите в датафрейме movies фильм с movieId=3456. Какой у него год выпуска?
# P. S. Попробуйте найти movieId этого фильма в датафрейме ratings. Это будет ключом к ответу на следующее задание.

movies[movies.movieId == 3456]
ratings[ratings.movieId == 3456]
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %%
sd =

def delete_rubles(var):
    return a[::-3]

a.apply(delete_rubles)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-d9089038a08b> in <module>
#       4     return a[::-3]
#       5
# ----> 6 a.apply(delete_rubles)
#
# AttributeError: 'str' object has no attribute 'apply'
